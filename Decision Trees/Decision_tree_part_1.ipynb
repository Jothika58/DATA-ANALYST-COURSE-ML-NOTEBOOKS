# %% [markdown]
# <h1 align='center' style='color:purple'><b>Decision Trees - Part 1</b></h1>

# %% [markdown]
# A decision tree follows tree-like model of decisions and their possible outcomes. It is a way to represent an algorithm that only contains conditional control statements.
# It a flowchart-like structure. Each internal node represents a "test" on a feature whereas every branch represents the outcome of the test, & each terminal/leaf node represents the outcome which can be a continuous value or class label for regression and classification problem respectively.
#  - It is a Supervised Learning Algorithm.
#  - it can be used for both classification and regression problems.
#  - It can also handle non-linear data which was not possible in case of linear models
#
# Advantages :
#  - Simple and easy to understand and visualize
#  - Somewhat resistant to outliers
#  - No Feature Scaling is Required.
#
# Disadvantages :
#  - Overfitting
#  - High variance
#  - Not suitable for large Datasets

# %% [markdown]
# <b>Load the data that we will be using to train our model</b>
#
# Here we are using Titanic dataset which contains the data from one of the most infamous shipwrecks in history : The sinking of the Titanic.

# %%
# Upload Titanic Dataset
from google.colab import files 

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c2c63ce1-9c6d-4fb6-8882-92f82d96fca1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2c63ce1-9c6d-4fb6-8882-92f82d96fca1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.csv to titanic (1).csv

# %% [markdown]
# <b> Import Necessary Libraries</b>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# <b>Get the data<b/>

# %%
import pandas as pd 
import io 

df = pd.read_csv(io.BytesIO(uploaded['titanic.csv']),index_col=0) 
df.head()
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %% [markdown]
# <b>Data Dictionary</b>
#
# ##### Variable	& Definition
#  - Survived (Target) :	Survival of passenger	(0 = No, 1 = Yes)
#  - Pclass : Ticket class	(1 = 1st, 2 = 2nd, 3 = 3rd)
#  - Sex : Gender
#  - Age : Age in years
#  - Sibsp :	# of siblings / spouses aboard the Titanic
#  - Parch : # of parents / children aboard the Titanic
#  - Ticket :	Ticket number
#  - Fare :	Passenger fare
#  - Cabin : Cabin number
#  - Embarked :	Port of Embarkation	(C = Cherbourg, Q = Queenstown, S =  Southampton)

# %% [markdown]
# <b>Drop insignificant Variables<b/>

# %%
df.drop(['Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)

# %% [markdown]
# As a person's survival may not depend on these variables.

# %%
df.head()
# Out:
#              Survived  Pclass     Sex   Age     Fare
# PassengerId
# 1                   0       3    male  22.0   7.2500
# 2                   1       1  female  38.0  71.2833
# 3                   1       3  female  26.0   7.9250
# 4                   1       1  female  35.0  53.1000
# 5                   0       3    male  35.0   8.0500

# %% [markdown]
# <b>Separate Inputs and Target</b>

# %%
inputs = df.drop('Survived',axis='columns')
target = df.Survived

# %% [markdown]
# <b>Encode Categorical Variables 'Sex', as decision trees implemented in scikit-learn accepts numerical variables only.</b>

# %%
inputs.Sex = inputs.Sex.map({'male': 1, 'female': 2})

# %%
# print first 10 records
inputs.Age[:10]
# Out:
# PassengerId
# 1     22.0
# 2     38.0
# 3     26.0
# 4     35.0
# 5     35.0
# 6      NaN
# 7     54.0
# 8      2.0
# 9     27.0
# 10    14.0
# Name: Age, dtype: float64

# %% [markdown]
# <b>We can see that there are a few NaN values in Age. So we will  fill those missing values with the avergae age.</b>

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())

# %%
# print first 10 records
inputs.Age[:10]
# Out:
# PassengerId
# 1     22.000000
# 2     38.000000
# 3     26.000000
# 4     35.000000
# 5     35.000000
# 6     29.699118
# 7     54.000000
# 8      2.000000
# 9     27.000000
# 10    14.000000
# Name: Age, dtype: float64

# %% [markdown]
# The age of Passenger number 6 has been filled with the average age(29.699).

# %% [markdown]
# <b>Separate Training and Testing Data</b>

# %%
# import train_test_split from sklearn library
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.3)

# %% [markdown]
# Here test_size is used to specify test data size. 0.3 means 30% of data will be used for test data & remaining 70% will be used for training data.
#  X_train, y_train : inputs and target of training data
#  X_test, y_test : inputs and target of testing data

# %% [markdown]
# <b> Check the length of Traing and Testing Data</b>

# %%
print('Length of Training Data : {} that is 70% of original data.'.format(len(X_train)))
print('Length of Testing Data : {} that is 30% of original data.'.format(len(X_test)))
# Out:
# Length of Training Data : 623 that is 70% of original data.

# %% [markdown]
# <b>Import Decision Tree Classifier</b>
# In this project, our target variable is of binary data type. So a Classification model will be used.

# %%
from sklearn import tree

# initialize a Decision Tree classifier model.
model = tree.DecisionTreeClassifier()

# %% [markdown]
# <b>Model Training</b> : Fitting/Training a model means that you're making your model learn the relationship b/w predictors and target so that you can predict the future values of the target.

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# <b>After model training, make predictions for thet testing data.</b>

# %%
model_accuracy = model.score(X_test,y_test)
print('Print model accuracy =',round(model_accuracy,3))
# Out:
# Print model accuracy = 0.795

# %% [markdown]
# model.score(X_test,ytest) : This function takes a feature matrix X_test and the expected target values y_test. Then y_testis compared with thet Predictions for X_test & either accuracy (for classification) or R2 score (for regression) is returned.

# %% [markdown]
# <b> Plot Decision Tree </b>

# %%
# Initialize a figure and use figsize to control the size of the rendered image.
plt.figure(figsize=(120,110))

# Plot Decision tree
tree.plot_tree(model, filled=True)

#Here filled is boolean parameter (default value = False) When set to True, 
#it paints the decisiontree nodes to indicate majority class for classification problem.
# Out:
# [Text(3907.52578125, 5822.242105263158, 'X[1] <= 1.5\ngini = 0.474\nsamples = 623\nvalue = [382, 241]'),
#  Text(2453.0203125, 5507.526315789474, 'X[3] <= 26.269\ngini = 0.315\nsamples = 408\nvalue = [328, 80]'),
#  Text(881.4656249999999, 5192.8105263157895, 'X[2] <= 12.5\ngini = 0.217\nsamples = 291\nvalue = [255, 36]'),
#  Text(481.275, 4878.094736842106, 'X[2] <= 2.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(425.47499999999997, 4563.378947368421, 'X[0] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(369.67499999999995, 4248.663157894737, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(481.275, 4248.663157894737, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(537.0749999999999, 4563.378947368421, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(
 1730.9368421052632, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3961.7999999999997, 1730.9368421052632, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4129.2, 2675.0842105263155, 'X[3] <= 79.025\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(4073.3999999999996, 2360.3684210526317, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(4185.0, 2360.3684210526317, 'X[2] <= 59.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(4129.2, 2045.652631578947, 'X[3] <= 85.638\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(4073.3999999999996, 1730.9368421052632, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(4185.0, 1730.9368421052632, 'X[3] <= 97.765\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(4129.2, 1416.2210526315785, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4240.8, 1416.2210526315785, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(4240.8, 2045.652631578947, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4073.3999999999996, 2989.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4129.2, 3304.515789473684, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(4185.0, 3619.2315789473687, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4408.2, 4563.378947368421, 'X[3] <= 31.331\ngini = 0.367\nsamples = 33\nvalue = [25, 8]'),
#  Text(4352.4, 4248.663157894737, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(4464.0, 4248.663157894737, 'X[2] <= 30.85\ngini = 0.444\nsamples = 24\nvalue = [16, 8]'),
#  Text(4408.2, 3933.9473684210525, 'X[3] <= 39.344\ngini = 0.397\nsamples = 22\nvalue = [16, 6]'),
#  Text(4296.599999999999, 3619.2315789473687, 'X[2] <= 8.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(4240.8, 3304.515789473684, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(4352.4, 3304.515789473684, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(4519.8, 3619.2315789473687, 'X[2] <= 28.85\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(4464.0, 3304.515789473684, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(4575.599999999999, 3304.515789473684, 'X[3] <= 63.023\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(4519.8, 2989.8, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4631.4, 2989.8, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(4519.8, 3933.9473684210525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(5362.03125, 5507.526315789474, 'X[0] <= 2.5\ngini = 0.376\nsamples = 215\nvalue = [54, 161]'),
#  Text(4826.7, 5192.8105263157895, 'X[3] <= 13.396\ngini = 0.101\nsamples = 112\nvalue = [6, 106]'),
#  Text(4687.2, 4878.094736842106, 'X[2] <= 53.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(4631.4, 4563.378947368421, 'X[3] <= 12.675\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(4575.599999999999, 4248.663157894737, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(4687.2, 4248.663157894737, 'X[2] <= 26.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(4631.4, 3933.9473684210525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4743.0, 3933.9473684210525, 'X[2] <= 36.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(4687.2, 3619.2315789473687, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(4798.8, 3619.2315789473687, 'X[2] <= 39.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(4743.0, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4854.599999999999, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4743.0, 4563.378947368421, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4966.2, 4878.094736842106, 'X[2] <= 3.0\ngini = 0.059\nsamples = 98\nvalue = [3, 95]'),
#  Text(4854.599999999999, 4563.378947368421, 'X[0] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(4798.8, 4248.663157894737, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4910.4, 4248.663157894737, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5077.8, 4563.378947368421, 'X[2] <= 27.0\ngini = 0.041\nsamples = 96\nvalue = [2, 94]'),
#  Text(5022.0, 4248.663157894737, 'X[2] <= 24.5\ngini = 0.111\nsamples = 34\nvalue = [2, 32]'),
#  Text(4966.2, 3933.9473684210525, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(5077.8, 3933.9473684210525, 'X[3] <= 115.2\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(5022.0, 3619.2315789473687, 'X[3] <= 52.425\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(4966.2, 3304.515789473684, 'X[2] <= 25.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(4910.4, 2989.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5022.0, 2989.8, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5077.8, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5133.599999999999, 3619.2315789473687, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5133.599999999999, 4248.663157894737, 'gini = 0.0\nsamples = 62\nvalue = [0, 62]'),
#  Text(5897.362499999999, 5192.8105263157895, 'X[3] <= 24.808\ngini = 0.498\nsamples = 103\nvalue = [48, 55]'),
#  Text(5642.775, 4878.094736842106, 'X[3] <= 8.04\ngini = 0.483\nsamples = 91\nvalue = [37, 54]'),
#  Text(5301.0, 4563.378947368421, 'X[2] <= 30.1\ngini = 0.408\nsamples = 35\nvalue = [10, 25]'),
#  Text(5245.2, 4248.663157894737, 'X[3] <= 6.987\ngini = 0.342\nsamples = 32\nvalue = [7, 25]'),
#  Text(5189.4, 3933.9473684210525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5301.0, 3933.9473684210525, 'X[3] <= 7.744\ngini = 0.312\nsamples = 31\nvalue = [6, 25]'),
#  Text(5245.2, 3619.2315789473687, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(5356.799999999999, 3619.2315789473687, 'X[2] <= 14.5\ngini = 0.365\nsamples = 25\nvalue = [6, 19]'),
#  Text(5301.0, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5412.599999999999, 3304.515789473684, 'X[3] <= 7.781\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(5301.0, 2989.8, 'X[2] <= 18.5\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(5245.2, 2675.0842105263155, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5356.799999999999, 2675.0842105263155, 'X[2] <= 21.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(5301.0, 2360.3684210526317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5412.599999999999, 2360.3684210526317, 'X[2] <= 23.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(5356.799999999999, 2045.652631578947, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(5468.4, 2045.652631578947, 'X[2] <= 27.35\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(5412.599999999999, 1730.9368421052632, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5524.2, 1730.9368421052632, 'gini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(5524.2, 2989.8, 'X[3] <= 7.888\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(5468.4, 2675.0842105263155, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(5580.0, 2675.0842105263155, 'X[2] <= 27.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(5524.2, 2360.3684210526317, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(5635.799999999999, 2360.3684210526317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5356.799999999999, 4248.663157894737, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(5984.549999999999, 4563.378947368421, 'X[3] <= 10.825\ngini = 0.499\nsamples = 56\nvalue = [27, 29]'),
#  Text(5747.4, 4248.663157894737, 'X[2] <= 30.5\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(5635.799999999999, 3933.9473684210525, 'X[2] <= 19.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(5580.0, 3619.2315789473687, 'X[2] <= 10.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(5524.2, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5635.799999999999, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5691.599999999999, 3619.2315789473687, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(5859.0, 3933.9473684210525, 'X[2] <= 35.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(5803.2, 3619.2315789473687, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5914.799999999999, 3619.2315789473687, 'X[3] <= 9.531\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(5859.0, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5970.599999999999, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6221.7, 4248.663157894737, 'X[3] <= 13.908\ngini = 0.464\nsamples = 41\nvalue = [15, 26]'),
#  Text(6165.9, 3933.9473684210525, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(6277.5, 3933.9473684210525, 'X[3] <= 15.373\ngini = 0.493\nsamples = 34\nvalue = [15, 19]'),
#  Text(6138.0, 3619.2315789473687, 'X[2] <= 29.35\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(6082.2, 3304.515789473684, 'X[2] <= 28.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(6026.4, 2989.8, 'X[2] <= 16.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(5970.599999999999, 2675.0842105263155, 'X[3] <= 14.85\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(5914.799999999999, 2360.3684210526317, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6026.4, 2360.3684210526317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6082.2, 2675.0842105263155, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(6138.0, 2989.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6193.799999999999, 3304.515789473684, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(6417.0, 3619.2315789473687, 'X[3] <= 20.8\ngini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(6305.4, 3304.515789473684, 'X[3] <= 18.629\ngini = 0.346\nsamples = 18\nvalue = [4, 14]'),
#  Text(6249.599999999999, 2989.8, 'X[3] <= 17.7\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(6193.799999999999, 2675.0842105263155, 'X[2] <= 25.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(6138.0, 2360.3684210526317, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(6249.599999999999, 2360.3684210526317, 'X[2] <= 27.85\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(6193.799999999999, 2045.652631578947, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6305.4, 2045.652631578947, 'X[2] <= 30.85\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(6249.599999999999, 1730.9368421052632, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(6361.2, 1730.9368421052632, 'X[3] <= 15.675\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(6305.4, 1416.2210526315785, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6417.0, 1416.2210526315785, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(6305.4, 2675.0842105263155, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(6361.2, 2989.8, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(6528.599999999999, 3304.515789473684, 'X[3] <= 21.717\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(6472.799999999999, 2989.8, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(6584.4, 2989.8, 'X[2] <= 29.85\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(6528.599999999999, 2675.0842105263155, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(6640.2, 2675.0842105263155, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6151.95, 4878.094736842106, 'X[2] <= 5.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(6096.15, 4563.378947368421, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6207.75, 4563.378947368421, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]')]

# %% [markdown]
# <b>Build a text report showing the rules of the Decision Tree model.</b>

# %%
print(tree.export_text(model))
# Out:
# |--- feature_1 <= 1.50
# |   |--- feature_3 <= 26.27
# |   |   |--- feature_2 <= 12.50
# |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |--- feature_0 <= 2.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  2.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |--- class: 1
# |   |   |--- feature_2 >  12.50
# |   |   |   |--- feature_3 <= 7.91
# |   |   |   |   |--- feature_2 <= 32.50
# |   |   |   |   |   |--- feature_3 <= 7.24
# |   |   |   |   |   |   |--- feature_2 <= 27.00
# |   |   |   |   |   |   |   |--- feature_2 <= 19.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  19.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2.01
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  2.01
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  21.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_2 >  27.00
# |   |   |   |   |   |   |   |--- feature_3 <= 7.23
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  7.23
# |   |   |   |   |   |   |   |   |--- feature_2 <= 29.85
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  29.85
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  7.24
# |   |   |   |   |   |   |--- feature_2 <= 31.50
# |   |   |   |   |   |   |   |--- feature_3 <= 7.75
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  7.75
# |   |   |   |   |   |   |   |   |--- feature_3 <= 7.80
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.79
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.76
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.76
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.79
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  7.80
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 29.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  29.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  31.50
# |   |   |   |   |   |   |   |--- feature_3 <= 7.80
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  7.80
# |   |   |   |   |   |   |   |   |--- feature_3 <= 7.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  7.88
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  32.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  7.91
# |   |   |   |   |--- feature_3 <= 7.99
# |   |   |   |   |   |--- feature_2 <= 20.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  20.50
# |   |   |   |   |   |   |--- feature_2 <= 29.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  29.50
# |   |   |   |   |   |   |   |--- feature_2 <= 31.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  31.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 41.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 38.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  34.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  38.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  41.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  7.99
# |   |   |   |   |   |--- feature_2 <= 32.50
# |   |   |   |   |   |   |--- feature_2 <= 28.75
# |   |   |   |   |   |   |   |--- feature_2 <= 20.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 17.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  17.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 14.37
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  8.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  14.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  20.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 18.29
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8.83
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  8.83
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  18.29
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 19.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  19.68
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  28.75
# |   |   |   |   |   |   |   |--- feature_2 <= 31.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 8.08
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  8.08
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 15.37
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  8.29
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  15.37
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 21.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  21.61
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_2 >  31.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  2.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  8.21
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  32.50
# |   |   |   |   |   |   |--- feature_3 <= 12.94
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  12.94
# |   |   |   |   |   |   |   |--- feature_3 <= 13.25
# |   |   |   |   |   |   |   |   |--- feature_2 <= 45.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 36.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  36.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  45.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  13.25
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |--- feature_3 >  26.27
# |   |   |--- feature_3 <= 26.47
# |   |   |   |--- class: 1
# |   |   |--- feature_3 >  26.47
# |   |   |   |--- feature_0 <= 1.50
# |   |   |   |   |--- feature_2 <= 17.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  17.50
# |   |   |   |   |   |--- feature_3 <= 59.09
# |   |   |   |   |   |   |--- feature_3 <= 52.28
# |   |   |   |   |   |   |   |--- feature_3 <= 38.95
# |   |   |   |   |   |   |   |   |--- feature_2 <= 28.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  28.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 58.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 31.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  31.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  58.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  72.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  38.95
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  52.28
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  59.09
# |   |   |   |   |   |   |--- feature_3 <= 387.66
# |   |   |   |   |   |   |   |--- feature_3 <= 134.64
# |   |   |   |   |   |   |   |   |--- feature_3 <= 116.64
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 26.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  22.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  26.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 79.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  79.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_3 >  116.64
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  134.64
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  387.66
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  1.50
# |   |   |   |   |--- feature_3 <= 31.33
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  31.33
# |   |   |   |   |   |--- feature_2 <= 30.85
# |   |   |   |   |   |   |--- feature_3 <= 39.34
# |   |   |   |   |   |   |   |--- feature_2 <= 8.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  8.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  39.34
# |   |   |   |   |   |   |   |--- feature_2 <= 28.85
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  28.85
# |   |   |   |   |   |   |   |   |--- feature_3 <= 63.02
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  63.02
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  30.85
# |   |   |   |   |   |   |--- class: 1
# |--- feature_1 >  1.50
# |   |--- feature_0 <= 2.50
# |   |   |--- feature_3 <= 13.40
# |   |   |   |--- feature_2 <= 53.50
# |   |   |   |   |--- feature_3 <= 12.68
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  12.68
# |   |   |   |   |   |--- feature_2 <= 26.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  26.00
# |   |   |   |   |   |   |--- feature_2 <= 36.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  36.00
# |   |   |   |   |   |   |   |--- feature_2 <= 39.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  39.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  53.50
# |   |   |   |   |--- class: 0
# |   |   |--- feature_3 >  13.40
# |   |   |   |--- feature_2 <= 3.00
# |   |   |   |   |--- feature_0 <= 1.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  1.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  3.00
# |   |   |   |   |--- feature_2 <= 27.00
# |   |   |   |   |   |--- feature_2 <= 24.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  24.50
# |   |   |   |   |   |   |--- feature_3 <= 115.20
# |   |   |   |   |   |   |   |--- feature_3 <= 52.42
# |   |   |   |   |   |   |   |   |--- feature_2 <= 25.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  25.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  52.42
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  115.20
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  27.00
# |   |   |   |   |   |--- class: 1
# |   |--- feature_0 >  2.50
# |   |   |--- feature_3 <= 24.81
# |   |   |   |--- feature_3 <= 8.04
# |   |   |   |   |--- feature_2 <= 30.10
# |   |   |   |   |   |--- feature_3 <= 6.99
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  6.99
# |   |   |   |   |   |   |--- feature_3 <= 7.74
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  7.74
# |   |   |   |   |   |   |   |--- feature_2 <= 14.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  14.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 7.78
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  18.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  21.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_3 >  7.78
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.89
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.89
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  27.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  30.10
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  8.04
# |   |   |   |   |--- feature_3 <= 10.82
# |   |   |   |   |   |--- feature_2 <= 30.50
# |   |   |   |   |   |   |--- feature_2 <= 19.00
# |   |   |   |   |   |   |   |--- feature_2 <= 10.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  10.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  19.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  30.50
# |   |   |   |   |   |   |--- feature_2 <= 35.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  35.50
# |   |   |   |   |   |   |   |--- feature_3 <= 9.53
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  9.53
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  10.82
# |   |   |   |   |   |--- feature_3 <= 13.91
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  13.91
# |   |   |   |   |   |   |--- feature_3 <= 15.37
# |   |   |   |   |   |   |   |--- feature_2 <= 29.35
# |   |   |   |   |   |   |   |   |--- feature_2 <= 28.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 16.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 14.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  14.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  16.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  28.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  29.35
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  15.37
# |   |   |   |   |   |   |   |--- feature_3 <= 20.80
# |   |   |   |   |   |   |   |   |--- feature_3 <= 18.63
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 17.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 25.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  25.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  17.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  18.63
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  20.80
# |   |   |   |   |   |   |   |   |--- feature_3 <= 21.72
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  21.72
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 29.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  29.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_3 >  24.81
# |   |   |   |--- feature_2 <= 5.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  5.50
# |   |   |   |   |--- class: 0

# %% [markdown]
# [<b> Minimal Cost-Complexity Pruning</b>](https://scikit-learn.org/stable/auto_examples/tree/plot_cost_complexity_pruning.html)
# Minimal cost-complexity pruning is an algorithm used to prune a tree to avoid over-fitting. This pruning technique is parameterized by the cost complexity parameter, ccp_alpha. Greater values of ccp_alpha increase the number of nodes pruned.
# ccp_alpha : (non-negative float, default=0.0)
# Complexity parameter used for Minimal Cost-Complexity Pruning. The subtree with the largest cost complexity that is smaller than ccp_alpha will be chosen. By default, no pruning is performed.

# %%
path = model.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
ccp_alphas
# Out:
# array([0.00000000e+00, 4.01284109e-05, 1.32187707e-04, 1.60513644e-04,
#        2.67522739e-04, 4.53214994e-04, 5.35045479e-04, 5.35045479e-04,
#        5.35045479e-04, 6.24219725e-04, 6.68806849e-04, 7.72269330e-04,
#        8.02568218e-04, 8.02568218e-04, 8.62017716e-04, 9.17220821e-04,
#        9.69242300e-04, 1.07009096e-03, 1.07009096e-03, 1.07009096e-03,
#        1.07009096e-03, 1.07009096e-03, 1.07009096e-03, 1.07009096e-03,
#        1.07597058e-03, 1.16737195e-03, 1.19497237e-03, 1.27244790e-03,
#        1.28410915e-03, 1.28410915e-03, 1.31329345e-03, 1.34447325e-03,
#        1.34525720e-03, 1.35819237e-03, 1.41312415e-03, 1.42704083e-03,
#        1.44873853e-03, 1.47137507e-03, 1.53143119e-03, 1.69114673e-03,
#        1.73049835e-03, 1.97775740e-03, 2.02260136e-03, 2.13288584e-03,
#        2.37491154e-03, 2.42321265e-03, 2.60049088e-03, 2.62172285e-03,
#        2.78223649e-03, 2.94275013e-03, 3.47293156e-03, 3.85232745e-03,
#        4.09183342e-03, 4.74135119e-03, 4.89577189e-03, 7.46969930e-03,
#        8.85507974e-03, 1.70604889e-02, 2.93019901e-02, 1.38109585e-01])

# %% [markdown]
# DecisionTreeClassifier.cost_complexity_pruning_path : returns the effective alphas and the corresponding total leaf impurities at each step of the pruning process. As alpha increases, more of the tree is pruned, which increases the total impurity of its leaves.

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <b>For each value of ccp_alpha, train a DecisionTree model and store it in models.</b>

# %%
models = []
for ccp_alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    model.fit(X_train, y_train)
    models.append(model)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      models[-1].tree_.node_count, ccp_alphas[-1]))
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.13810958534022977

# %% [markdown]
# <b>For all the models trained for different values of ccp_alpha, find training and testing accuracy and plot it.</b>

# %%
# Calculate train and test accuracy of all the models
train_scores = [model.score(X_train, y_train) for model in models]
test_scores = [model.score(X_test, y_test) for model in models]

# plot training and testingaccuracy
fig, ax = plt.subplots(figsize = (18,6))
ax.set_xlabel("alpha", fontsize = 14)
ax.set_ylabel("Accuracy", fontsize = 14)
ax.set_title("Accuracy vs alpha for training and testing sets", fontsize = 16)
ax.plot(ccp_alphas, train_scores, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
#  - From the above plot, it is clear that around 0.003 ccp_alpha, model accuracy for test data is highest.
#  - It can also be noted that near 0.003 ccp_alpha, training and testing accuracies are almost equal which means model is not over-fitting.

# %% [markdown]
# <b> Train Final Decision tree model with the selected value of ccp_alpha.</b>

# %%
model = DecisionTreeClassifier(random_state=0, ccp_alpha=0.003)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.003, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
# Make predictions for testing data
pred=model.predict(X_test)

# Import accuracy_score, which also calculates the accuracy of predictions
from sklearn.metrics import accuracy_score
print('Model accuracy after post-pruning :',round(accuracy_score(y_test, pred),3))
# Out:
# Model accuracy after post-pruning : 0.847

# %% [markdown]
# The model accuracy after post pruning increased. This shows that without post pruning, our initial decisionTree model was over-fitting on the training data.

# %% [markdown]
# <b> Lets visualize our final DecisonTree model to observe the effect of post-pruning. </b>

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model,filled=True)
# Out:
# [Text(378.6428571428571, 516.4200000000001, 'X[1] <= 1.5\ngini = 0.474\nsamples = 623\nvalue = [382, 241]'),
#  Text(159.42857142857142, 462.06000000000006, 'X[3] <= 26.269\ngini = 0.315\nsamples = 408\nvalue = [328, 80]'),
#  Text(79.71428571428571, 407.70000000000005, 'X[2] <= 12.5\ngini = 0.217\nsamples = 291\nvalue = [255, 36]'),
#  Text(39.857142857142854, 353.34000000000003, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(119.57142857142856, 353.34000000000003, 'gini = 0.199\nsamples = 286\nvalue = [254, 32]'),
#  Text(239.1428571428571, 407.70000000000005, 'X[3] <= 26.469\ngini = 0.469\nsamples = 117\nvalue = [73, 44]'),
#  Text(199.28571428571428, 353.34000000000003, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(279.0, 353.34000000000003, 'X[0] <= 1.5\ngini = 0.461\nsamples = 114\nvalue = [73, 41]'),
#  Text(199.28571428571428, 298.98, 'X[2] <= 17.5\ngini = 0.483\nsamples = 81\nvalue = [48, 33]'),
#  Text(159.42857142857142, 244.62, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(239.1428571428571, 244.62, 'X[3] <= 59.087\ngini = 0.47\nsamples = 77\nvalue = [48, 29]'),
#  Text(199.28571428571428, 190.26000000000005, 'X[3] <= 52.277\ngini = 0.499\nsamples = 46\nvalue = [24, 22]'),
#  Text(159.42857142857142, 135.90000000000003, 'X[3] <= 38.95\ngini = 0.48\nsamples = 40\nvalue = [24, 16]'),
#  Text(119.57142857142856, 81.54000000000002, 'X[2] <= 28.5\ngini = 0.498\nsamples = 34\nvalue = [18, 16]'),
#  Text(79.71428571428571, 27.180000000000064, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(159.42857142857142, 27.180000000000064, 'gini = 0.48\nsamples = 30\nvalue = [18, 12]'),
#  Text(199.28571428571428, 81.54000000000002, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(239.1428571428571, 135.90000000000003, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(279.0, 190.26000000000005, 'gini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(358.71428571428567, 298.98, 'X[3] <= 31.331\ngini = 0.367\nsamples = 33\nvalue = [25, 8]'),
#  Text(318.85714285714283, 244.62, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(398.57142857142856, 244.62, 'X[2] <= 30.85\ngini = 0.444\nsamples = 24\nvalue = [16, 8]'),
#  Text(358.71428571428567, 190.26000000000005, 'X[3] <= 39.344\ngini = 0.397\nsamples = 22\nvalue = [16, 6]'),
#  Text(318.85714285714283, 135.90000000000003, 'X[2] <= 8.5\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(279.0, 81.54000000000002, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(358.71428571428567, 81.54000000000002, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(398.57142857142856, 135.90000000000003, 'gini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(438.4285714285714, 190.26000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(597.8571428571428, 462.06000000000006, 'X[0] <= 2.5\ngini = 0.376\nsamples = 215\nvalue = [54, 161]'),
#  Text(558.0, 407.70000000000005, 'gini = 0.101\nsamples = 112\nvalue = [6, 106]'),
#  Text(637.7142857142857, 407.70000000000005, 'X[3] <= 24.808\ngini = 0.498\nsamples = 103\nvalue = [48, 55]'),
#  Text(597.8571428571428, 353.34000000000003, 'X[3] <= 8.04\ngini = 0.483\nsamples = 91\nvalue = [37, 54]'),
#  Text(518.1428571428571, 298.98, 'X[2] <= 30.1\ngini = 0.408\nsamples = 35\nvalue = [10, 25]'),
#  Text(478.2857142857142, 244.62, 'gini = 0.342\nsamples = 32\nvalue = [7, 25]'),
#  Text(558.0, 244.62, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(677.5714285714286, 298.98, 'X[3] <= 10.825\ngini = 0.499\nsamples = 56\nvalue = [27, 29]'),
#  Text(637.7142857142857, 244.62, 'gini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(717.4285714285713, 244.62, 'X[3] <= 13.908\ngini = 0.464\nsamples = 41\nvalue = [15, 26]'),
#  Text(677.5714285714286, 190.26000000000005, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(757.2857142857142, 190.26000000000005, 'X[3] <= 15.373\ngini = 0.493\nsamples = 34\nvalue = [15, 19]'),
#  Text(717.4285714285713, 135.90000000000003, 'gini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(797.1428571428571, 135.90000000000003, 'gini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(677.5714285714286, 353.34000000000003, 'gini = 0.153\nsamples = 12\nvalue = [11, 1]')]

# %% [markdown]
# <b>It can be observed that after post-pruning, the size of decision tree reduced.</b>
